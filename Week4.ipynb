# %%
import numpy as np # library to handle data in a vectorized manner
# !pip install geopy
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Libraries imported.

# %%
# !pip install lxml
import lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)

# %%
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/lib/python3.9/site-packages (4.6.2)

# %% [markdown]
# **Assignement description**
#
# Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve. If you cannot think of an idea or a problem, here are some ideas to get you started:
#
# In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are. Is New York City more like Toronto or Paris or some other multicultural city? I will leave it to you to refine this idea.
# In a city of your choice, if someone is looking to open a restaurant, where would you recommend that they open it? Similarly, if a contractor is trying to start their own business, where would you recommend that they setup their office?
# These are just a couple of many ideas and problems that can be solved using location data in addition to other datasets. No matter what you decide to do, make sure to provide sufficient justification of why you think what you want to do or solve is important and why would a client or a group of people be interested in your project.
#
#
# **For the purpose of this week's project I will explore the region of Cascais.**
#
# Cascais is located in Lisbon, Portugal.
#
# Regions in Portugal can drilled down from Distrito -> Concelho -> Freguesia -> Localidade.
# In this example, Lisbon is the 'Distrito, and we are going to explore Cascais which is a 'Concelho'.
#
# Let's imagine I am visiting Portugal and I really like italian food.
# The problem to be solved is in which Hotel should I be hosted in order to be closer to all the Italian Restaurants in Cascais.
#
# This Dataset is a subset of a dataset found on https://github.com/cusco/ctt. The referenced dataset contains all the streets across Portugal along with a lot more information. It might be a little outdated but it was the most complete way to find a list of 'Distritos', 'Concelhos', 'Municípios' and 'Localidades'.
#
# The loaded CSV is filtered by 'Concelho' = 'Cascais' for the sake of a smaller dataset size.

# %%
import lxml
table = pd.read_csv('ctt-lat-lng-cascais.csv', sep=';')

# %% [markdown]
# Removing unnecessary columns and duplicated rows to achieve a unique column of 'Localidade'

# %%
table_aux = table[['LOCALIDADE']].drop_duplicates()
table_final = table_aux.sort_values(by=['LOCALIDADE']).reset_index(drop=True)
table_final.head()
# Out:
#        LOCALIDADE
# 0         Abóboda
# 1        Alapraia
# 2     Alcabideche
# 3        Alcoitão
# 4  Aldeia de Juzo

# %%
# !pip install geocoder

import geocoder # import geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.25.0)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)

# %% [markdown]
# **Utilizing Geocoder to discover each 'Localidade''s coordinates**

# %%
latitude=[]
longitude=[]
for localidade in table_final['LOCALIDADE']:
    g = geocoder.arcgis('{}, Cascais, Portugal'.format(localidade))
    print(localidade, g.latlng)
    while (g.latlng is None):
        g = geocoder.arcgis('{}, Cascais, Portugal'.format(localidade))
        print(localidade, g.latlng)
    latlng = g.latlng
    latitude.append(latlng[0])
    longitude.append(latlng[1])
# Out:
# Abóboda [38.72556000000003, -9.333789999999965]
# Alapraia [38.707520000000045, -9.375459999999975]
# Alcabideche [38.73380000000003, -9.408969999999954]
# Alcoitão [38.734950000000026, -9.39656999999994]
# Aldeia de Juzo [38.72977000000003, -9.448019999999929]
# Alto dos Campitos [39.21372000000008, -8.418949999999938]
# Alto dos Gaios [38.71536000000003, -9.381419999999935]
# Alto dos Lombos [38.68936000000008, -9.329029999999932]
# Amoreira [38.71850000000006, -9.408829999999966]
# Areia [38.719070000000045, -9.462699999999927]
# Areias [38.72005000000007, -9.463629999999966]
# Arneiro [38.70661000000007, -9.326129999999978]
# Atibá [38.72312000000005, -9.380119999999977]
# Bairro da Martinha [38.72009000000003, -9.387139999999931]
# Bairro de Santo António [38.716980000000035, -9.405969999999968]
# Baixo dos Gaios [38.71357000000006, -9.378019999999935]
# Bicesse [38.730650000000026, -9.383979999999951]
# Birre [38.71637000000004, -9.448499999999967]
# Cabeço de Mouro [38.71377000000007, -9.332289999999944]
# Caparide [38.71561000000003, -9.358899999999949]
# Carcavelos [38.690300000000036, -9.337659999999971]
# Carrascal de Alvide [38.72368000000006, -9.423579999999959]
# Carrascal de Manique [38.73653767026809, -9.363811271360833]
# Cascais [38.69670000000008, -9.420399999999972]
# Charneca [38.73452000000003, -9.453519999999969]
# Cobre [38.71923000000004, -9.435639999999978]
# Conceição da Abóboda [38.73019000000005, -9.325849999999946]
# Estoril [38.703500000000076, -9.39769999999993]
# Galiza [38.70508234652646, -9.385088752147546]
# Guincho [38.729654157606774, -9.47316343885316]
# Janes [38.751280000000065, -9.441119999999955]
# Junqueiro [38.68617000000006, -9.347769999999969]
# Linhó [38.75543000000005, -9.384319999999946]
# Livramento [38.71162000000004, -9.373389999999972]
# Lombos [38.68530000000004, -9.328759999999932]
# Madorna [38.70048000000003, -9.354949999999974]
# Malveira da Serra [38.75251000000003, -9.44844999999998]
# Manique [38.737340000000074, -9.36907999999994]
# Manique de Baixo [38.73621000000003, -9.366079999999954]
# Matarraque [38.70781000000005, -9.353149999999971]
# Matos Cheirinhos [38.72287000000006, -9.341369999999927]
# Monte Estoril [38.70449000000008, -9.405079999999941]
# Monte Leite [38.70509275601523, -9.389347356952989]
# Murches [38.73106000000007, -9.439869999999928]
# Murtal [38.70199000000008, -9.366979999999955]
# Outeiro de Polima [38.71660000000003, -9.32573999999994]
# Pai do Vento [38.71532000000008, -9.415439999999933]
# Parede [38.68726000000004, -9.358809999999949]
# Penedo [38.706300000000056, -9.358429999999942]
# Polima [38.724500000000035, -9.323659999999961]
# Ponte das Varandas [38.73606257301204, -9.318958829092287]
# Quenena [38.69670000000008, -9.420399999999972]
# Quinta da Marinha [38.699470130061684, -9.464092729642784]
# Rana [38.69804000000005, -9.348589999999945]
# Rebelva [38.69598000000008, -9.340469999999925]
# Ribeira da Penha Longa [38.753720000000044, -9.39689999999996]
# Sassoeiros [38.70162000000005, -9.32729999999998]
# São Domingos de Rana [38.70275000000004, -9.342179999999928]
# São João do Estoril [38.704390000000046, -9.387689999999964]
# São Pedro do Estoril [38.694300000000055, -9.373899999999935]
# Talaíde [38.736770000000035, -9.31200999999993]
# Tires [38.71840000000003, -9.34701999999993]
# Torre [38.70611000000008, -9.442049999999938]
# Trajouce [38.73724000000004, -9.33949999999993]
# Zambujal [38.70425000000006, -9.345449999999971]
# Zambujeiro [38.74225000000007, -9.435779999999966]

# %% [markdown]
# Adding the values from Geocoder to the data frame.

# %%
se_lat = pd.Series(latitude)
se_lon = pd.Series(longitude)
table_final['Latitude'] = se_lat.values
table_final['Longitude'] = se_lon.values

# %%
table_final
# Out:
#                  LOCALIDADE   Latitude  Longitude
# 0                   Abóboda  38.725560  -9.333790
# 1                  Alapraia  38.707520  -9.375460
# 2               Alcabideche  38.733800  -9.408970
# 3                  Alcoitão  38.734950  -9.396570
# 4            Aldeia de Juzo  38.729770  -9.448020
# 5         Alto dos Campitos  39.213720  -8.418950
# 6            Alto dos Gaios  38.715360  -9.381420
# 7           Alto dos Lombos  38.689360  -9.329030
# 8                  Amoreira  38.718500  -9.408830
# 9                     Areia  38.719070  -9.462700
# 10                   Areias  38.720050  -9.463630
# 11                  Arneiro  38.706610  -9.326130
# 12                    Atibá  38.723120  -9.380120
# 13       Bairro da Martinha  38.720090  -9.387140
# 14  Bairro de Santo António  38.716980  -9.405970
# 15          Baixo dos Gaios  38.713570  -9.378020
# 16                  Bicesse  38.730650  -9.383980
# 17                    Birre  38.716370  -9.448500
# 18          Cabeço de Mouro  38.713770  -9.332290
# 19                 Caparide  38.715610  -9.358900
# 20               Carcavelos  38.690300  -9.337660
# 21      Carrascal de Alvide  38.723680  -9.423580
# 22     Carrascal de Manique  38.736538  -9.363811
# 23                  Cascais  38.696700  -9.420400
# 24                 Charneca  38.734520  -9.453520
# 25                    Cobre  38.719230  -9.435640
# 26     Conceição da Abóboda  38.730190  -9.325850
# 27                  Estoril  38.703500  -9.397700
# 28                   Galiza  38.705082  -9.385089
# 29                  Guincho  38.729654  -9.473163
# 30                    Janes  38.751280  -9.441120
# 31                Junqueiro  38.686170  -9.347770
# 32                    Linhó  38.755430  -9.384320
# 33               Livramento  38.711620  -9.373390
# 34                   Lombos  38.685300  -9.328760
# 35                  Madorna  38.700480  -9.354950
# 36        Malveira da Serra  38.752510  -9.448450
# 37                  Manique  38.737340  -9.369080
# 38         Manique de Baixo  38.736210  -9.366080
# 39               Matarraque  38.707810  -9.353150
# 40         Matos Cheirinhos  38.722870  -9.341370
# 41            Monte Estoril  38.704490  -9.405080
# 42              Monte Leite  38.705093  -9.389347
# 43                  Murches  38.731060  -9.439870
# 44                   Murtal  38.701990  -9.366980
# 45        Outeiro de Polima  38.716600  -9.325740
# 46             Pai do Vento  38.715320  -9.415440
# 47                   Parede  38.687260  -9.358810
# 48                   Penedo  38.706300  -9.358430
# 49                   Polima  38.724500  -9.323660
# 50       Ponte das Varandas  38.736063  -9.318959
# 51                  Quenena  38.696700  -9.420400
# 52        Quinta da Marinha  38.699470  -9.464093
# 53                     Rana  38.698040  -9.348590
# 54                  Rebelva  38.695980  -9.340470
# 55   Ribeira da Penha Longa  38.753720  -9.396900
# 56               Sassoeiros  38.701620  -9.327300
# 57     São Domingos de Rana  38.702750  -9.342180
# 58      São João do Estoril  38.704390  -9.387690
# 59     São Pedro do Estoril  38.694300  -9.373900
# 60                  Talaíde  38.736770  -9.312010
# 61                    Tires  38.718400  -9.347020
# 62                    Torre  38.706110  -9.442050
# 63                 Trajouce  38.737240  -9.339500
# 64                 Zambujal  38.704250  -9.345450
# 65               Zambujeiro  38.742250  -9.435780

# %% [markdown]
# **Lets draw a map with the 'Localidades' on the 'Concelho' of Cascais using Folium**

# %%
address = 'Cascais'

geolocator = Nominatim(user_agent="cascais_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Cascais are {}, {}.'.format(latitude, longitude))

map_cascais = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, localidade in zip(table_final['Latitude'], table_final['Longitude'], table_final['LOCALIDADE']):
    label = '{}'.format(localidade)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cascais)  
    
map_cascais
# Out:
# The geograpical coordinate of Cascais are 38.72240025, -9.396909171649877.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Apparently the lat and lon of 'Localidade' Alto dos Campitos isn't being well scrapped.
#
# If we zoom out once we can see it being really far from Cascais.
# By searching on google we can find that Alto dos Campitos is near Estoril so we are going to scrape it with that additional information

# %%
localidade_missing = 'Alto dos Campitos'
g_missing = geocoder.arcgis('{}, Estoril, Cascais, Portugal'.format(localidade_missing))
print(localidade_missing, g_missing.latlng)
# Out:
# Alto dos Campitos [38.703500000000076, -9.39769999999993]

# %% [markdown]
# Looks like we have a different set of coordinates which are inline with the remaining.
#
# Fixing it on the dataframe.

# %%
table_final.loc[table_final['LOCALIDADE'] == 'Alto dos Campitos']
# Out:
#           LOCALIDADE  Latitude  Longitude
# 5  Alto dos Campitos  39.21372   -8.41895

# %%
table_final.loc[table_final['LOCALIDADE'] == 'Alto dos Campitos', ['Latitude']] = g_missing.latlng[0]
table_final.loc[table_final['LOCALIDADE'] == 'Alto dos Campitos', ['Longitude']] = g_missing.latlng[1]

# %% [markdown]
# **Lets check if it was fixed**

# %%
table_final.loc[table_final['LOCALIDADE'] == 'Alto dos Campitos']
# Out:
#           LOCALIDADE  Latitude  Longitude
# 5  Alto dos Campitos   38.7035    -9.3977

# %% [markdown]
# **It appears to be fixed so lets redraw**

# %%
address = 'Cascais'

geolocator = Nominatim(user_agent="cascais_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Cascais are {}, {}.'.format(latitude, longitude))

map_cascais = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, localidade in zip(table_final['Latitude'], table_final['Longitude'], table_final['LOCALIDADE']):
    label = '{}'.format(localidade)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cascais)  
    
map_cascais
# Out:
# The geograpical coordinate of Cascais are 38.72240025, -9.396909171649877.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **We are all set with our dataset so let's get started with Foursquare**

# %% [markdown]
# Defining Foursquare setup

# %%
CLIENT_ID = 'JVGQLQH2OVHJ2QN4QX23HUROFWLCBGFEYKIVMRFQAQZQZYX0' # your Foursquare ID
CLIENT_SECRET = 'QMSOEHVVSPFIY43L5SS1GLXT2XS5S1MC5MZR4BB50XMUZG3K' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# **Reusing the Function definition to iterate over a list of locations and its coordinates**
#
# Utilizing a Radius of 5000 to make sure we don't miss any possible venues, we will delete the duplicates due to overlapping radius later

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Calling the previously defined function to retrieve all the venues of the dataframe's 'Localidades'

# %%
cascais_venues = getNearbyVenues(names=table_final['LOCALIDADE'],
                                   latitudes=table_final['Latitude'],
                                   longitudes=table_final['Longitude']
                                  )
# Out:
# Abóboda
# Alapraia
# Alcabideche
# Alcoitão
# Aldeia de Juzo
# Alto dos Campitos
# Alto dos Gaios
# Alto dos Lombos
# Amoreira
# Areia
# Areias
# Arneiro
# Atibá
# Bairro da Martinha
# Bairro de Santo António
# Baixo dos Gaios
# Bicesse
# Birre
# Cabeço de Mouro
# Caparide
# Carcavelos
# Carrascal de Alvide
# Carrascal de Manique
# Cascais
# Charneca
# Cobre
# Conceição da Abóboda
# Estoril
# Galiza
# Guincho
# Janes
# Junqueiro
# Linhó
# Livramento
# Lombos
# Madorna
# Malveira da Serra
# Manique
# Manique de Baixo
# Matarraque
# Matos Cheirinhos
# Monte Estoril
# Monte Leite
# Murches
# Murtal
# Outeiro de Polima
# Pai do Vento
# Parede
# Penedo
# Polima
# Ponte das Varandas
# Quenena
# Quinta da Marinha
# Rana
# Rebelva
# Ribeira da Penha Longa
# Sassoeiros
# São Domingos de Rana
# São João do Estoril
# São Pedro do Estoril
# Talaíde
# Tires
# Torre
# Trajouce
# Zambujal
# Zambujeiro

# %% [markdown]
# **List head venues**

# %%
print(cascais_venues.shape)
cascais_venues.head()
# Out:
# (6532, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Abóboda               38.72556                -9.33379
# 1      Abóboda               38.72556                -9.33379
# 2      Abóboda               38.72556                -9.33379
# 3      Abóboda               38.72556                -9.33379
# 4      Abóboda               38.72556                -9.33379
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0                Burger King       38.724053        -9.336372
# 1              Bugio Terrace       38.712962        -9.324767
# 2      Casa das Francesinhas       38.724810        -9.322853
# 3         Lagoas Health Club       38.714207        -9.309109
# 4  A Boa Petisqueira da Mina       38.706679        -9.323525
#
#           Venue Category
# 0   Fast Food Restaurant
# 1                 Lounge
# 2  Portuguese Restaurant
# 3   Gym / Fitness Center
# 4  Portuguese Restaurant

# %% [markdown]
# **Let's see the different venue types**

# %%
cascais_venues['Venue Category'].drop_duplicates()
# Out:
# 0                Fast Food Restaurant
# 1                              Lounge
# 2               Portuguese Restaurant
# 3                Gym / Fitness Center
# 5                                Café
# 7                                 Gym
# 9                               Hotel
# 11                 African Restaurant
# 12                     Ice Cream Shop
# 13                          Bookstore
# 14                             Garden
# 16                          BBQ Joint
# 17                               Park
# 19                             Bakery
# 20                Japanese Restaurant
# 23                        Art Gallery
# 25                              Beach
# 28                       Burger Joint
# 34                         Soup Place
# 35                 Chinese Restaurant
# 42               Brazilian Restaurant
# 44                              Trail
# 45                            Factory
# 47                           Pharmacy
# 50                 Seafood Restaurant
# 52                        Supermarket
# 55                            Airport
# 57                         Steakhouse
# 58                 Dim Sum Restaurant
# 62                  Indian Restaurant
# 65                            Brewery
# 66            Comfort Food Restaurant
# 68                         Restaurant
# 69                  Food & Drink Shop
# 70                        Coffee Shop
# 71                        Golf Course
# 72                   Tapas Restaurant
# 75                            Theater
# 77                  Paella Restaurant
# 82                   Asian Restaurant
# 84                   Sushi Restaurant
# 85                        Pizza Place
# 90                       Cocktail Bar
# 95                       Dessert Shop
# 96                Monument / Landmark
# 100                    Scenic Lookout
# 102                        Skate Park
# 109                      Tennis Court
# 111                       Candy Store
# 112                     Grocery Store
# 117                Italian Restaurant
# 127                         Nightclub
# 142             Performing Arts Venue
# 151                          Tea Room
# 159                               Bay
# 163                               Bar
# 167                          Wine Bar
# 170                            Casino
# 176                 Electronics Store
# 180                            Market
# 183                   Bed & Breakfast
# 184     Vegetarian / Vegan Restaurant
# 189             Outdoors & Recreation
# 190                         Surf Spot
# 195                     Train Station
# 196            Furniture / Home Store
# 198                     Movie Theater
# 203                         Racetrack
# 207                     Shopping Mall
# 255          Mediterranean Restaurant
# 258                            Resort
# 268                Athletics & Sports
# 269                          Beer Bar
# 272                        Art Museum
# 273                       Snack Place
# 280                               Pub
# 283                            Church
# 287                            Museum
# 290                        Lighthouse
# 381                       Gas Station
# 388                      Soccer Field
# 390                 Other Repair Shop
# 392                           Dog Run
# 395                              Food
# 420                             Plaza
# 454                 Fish & Chips Shop
# 482                        Food Court
# 492                   Paintball Field
# 495                     Historic Site
# 763                         Juice Bar
# 938                           Stables
# 962                               Spa
# 978                        Campground
# 1192                      Flower Shop
# 1355                   Cosmetics Shop
# 1373                        Rock Club
# 1672                    Big Box Store
# 2089                   Breakfast Spot
# 2238                 Department Store
# 2268       Construction & Landscaping
# 2269                        Multiplex
# 2288                   Clothing Store
# 2289                      Salad Place
# 2290                     Noodle House
# 2292                             Pool
# 2490                Health Food Store
# 2491                       Donut Shop
# 2492                   Soccer Stadium
# 2679                       Playground
# 2681              Martial Arts School
# 2695                   Farmers Market
# 2946                        Hotel Bar
# 2953                        Cafeteria
# 2954              Sporting Goods Shop
# 2956                           Hostel
# 3040                      Auto Garage
# 3041              Arts & Crafts Store
# 3054                             Lake
# 3183                           Palace
# 3187                          Exhibit
# 3195                           Castle
# 3216                    National Park
# 3225                         Fountain
# 3233                      Pastry Shop
# 3640               Falafel Restaurant
# 3651    Paper / Office Supplies Store
# 3654                 Toy / Game Store
# 3658                       Shoe Store
# 3857                      Karaoke Bar
# 5030                         Gym Pool
# 5032                       Kids Store
# 5035                      College Gym
# 5052                      Flea Market
# 6322             Other Great Outdoors
# 6329                           Arcade
# Name: Venue Category, dtype: object

# %% [markdown]
# **Filtering by Italian Restaurants and might aswell add Pizza Places**

# %%
cascais_italian_restaurants_aux = cascais_venues.loc[(cascais_venues['Venue Category'] == 'Italian Restaurant') | (cascais_venues['Venue Category'] == 'Pizza Place')]
cascais_italian_restaurants_aux.head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 85       Abóboda               38.72556                -9.33379
# 117     Alapraia               38.70752                -9.37546
# 122     Alapraia               38.70752                -9.37546
# 279  Alcabideche               38.73380                -9.40897
# 282  Alcabideche               38.73380                -9.40897
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 85                Trecento Sessanta       38.683681        -9.342899
# 117               Choupana Gordinni       38.697044        -9.381266
# 122  Lamassa - Fresh Handmade Pasta       38.703685        -9.393085
# 279                    Il Siciliano       38.697552        -9.421638
# 282                     Capricciosa       38.700902        -9.415504
#
#          Venue Category
# 85          Pizza Place
# 117  Italian Restaurant
# 122  Italian Restaurant
# 279  Italian Restaurant
# 282  Italian Restaurant

# %% [markdown]
# **Droping duplicates due to overlapping radius among 'Localidades'**

# %%
cascais_italian_restaurants= cascais_italian_restaurants_aux[['Venue','Venue Latitude','Venue Longitude','Venue Category']].drop_duplicates()
cascais_italian_restaurants.head()
# Out:
#                               Venue  Venue Latitude  Venue Longitude  \
# 85                Trecento Sessanta       38.683681        -9.342899
# 117               Choupana Gordinni       38.697044        -9.381266
# 122  Lamassa - Fresh Handmade Pasta       38.703685        -9.393085
# 279                    Il Siciliano       38.697552        -9.421638
# 282                     Capricciosa       38.700902        -9.415504
#
#          Venue Category
# 85          Pizza Place
# 117  Italian Restaurant
# 122  Italian Restaurant
# 279  Italian Restaurant
# 282  Italian Restaurant

# %% [markdown]
# **Let's draw the restaurants on the map**

# %%
address = 'Cascais'

geolocator = Nominatim(user_agent="cascais_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Cascais are {}, {}.'.format(latitude, longitude))

map_cascais_italian_restaurants = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, restaurant_name, restaurant_type in zip(cascais_italian_restaurants['Venue Latitude'], cascais_italian_restaurants['Venue Longitude'], cascais_italian_restaurants['Venue'], cascais_italian_restaurants['Venue Category'] ):
    label = '{}, {}'.format(restaurant_name,restaurant_type)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cascais_italian_restaurants)  
    
map_cascais_italian_restaurants
# Out:
# The geograpical coordinate of Cascais are 38.72240025, -9.396909171649877.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Let's now add all the possible places to be hosted to the map**
#
# First let's find out the Hotels, Resorts and Hostels near Cascais

# %%
cascais_bookings_aux = cascais_venues.loc[(cascais_venues['Venue Category'] == 'Hotel') | (cascais_venues['Venue Category'] == 'Resort') | (cascais_venues['Venue Category'] == 'Hostel') ]
cascais_bookings_aux.head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 9        Abóboda               38.72556                -9.33379
# 113     Alapraia               38.70752                -9.37546
# 125     Alapraia               38.70752                -9.37546
# 135     Alapraia               38.70752                -9.37546
# 139     Alapraia               38.70752                -9.37546
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 9                   Lagoas Park Hotel       38.714855        -9.309450
# 113  Palácio Estoril Hotel Golf & SPA       38.704751        -9.396607
# 125          InterContinental Estoril       38.704330        -9.405819
# 135     Somewhere Estoril Guest House       38.705316        -9.394970
# 139             Hotel Cascais Miragem       38.702467        -9.410972
#
#     Venue Category
# 9            Hotel
# 113          Hotel
# 125          Hotel
# 135          Hotel
# 139          Hotel

# %% [markdown]
# **Dropping the duplicates due to overlapping 'Localidade' radius**

# %%
cascais_bookings= cascais_bookings_aux[['Venue','Venue Latitude','Venue Longitude','Venue Category']].drop_duplicates()
cascais_bookings
# Out:
#                                               Venue  Venue Latitude  \
# 9                                 Lagoas Park Hotel       38.714855
# 113                Palácio Estoril Hotel Golf & SPA       38.704751
# 125                        InterContinental Estoril       38.704330
# 135                   Somewhere Estoril Guest House       38.705316
# 139                           Hotel Cascais Miragem       38.702467
# 210                              Penha Longa Resort       38.761407
# 257                              The Albatroz Hotel       38.699910
# 258            Grande Real Villa Itália Hotel e Spa       38.691037
# 263                                     Farol Hotel       38.690436
# 411                            Fortaleza do Guincho       38.728171
# 416                               The Oitavos Hotel       38.702798
# 424                               Martinhal Cascais       38.701860
# 429                         Sheraton Cascais Resort       38.710105
# 455          Senhora da Guia Cascais Boutique Hotel       38.696375
# 766    Hotel Vila Galé Collection Palácio dos Arcos       38.696575
# 971                  Hotel Quinta da Marinha Resort       38.707187
# 2276                             Ibis Lisboa Sintra       38.780450
# 2956                      Guincho Surf Beach Hostel       38.734984
# 2984          The Ritz Carlton - Penha Longa Resort       38.761060
# 3018                                Hotel Estoril 7       38.740338
# 3170  Pestana Sintra Golf   Conference & Spa Resort       38.762963
# 3219                Hotel Tivoli Palácio de Seteais       38.796708
# 3249                               Moon Hill Hostel       38.798649
# 6518                             Hotel Estoril Eden       38.703827
#
#       Venue Longitude Venue Category
# 9           -9.309450          Hotel
# 113         -9.396607          Hotel
# 125         -9.405819          Hotel
# 135         -9.394970          Hotel
# 139         -9.410972          Hotel
# 210         -9.397055          Hotel
# 257         -9.417177          Hotel
# 258         -9.424179         Resort
# 263         -9.422119          Hotel
# 411         -9.476295          Hotel
# 416         -9.466774          Hotel
# 424         -9.457446         Resort
# 429         -9.460854          Hotel
# 455         -9.456344          Hotel
# 766         -9.289266          Hotel
# 971         -9.456728          Hotel
# 2276        -9.353389          Hotel
# 2956        -9.455661         Hostel
# 2984        -9.396330          Hotel
# 3018        -9.399394          Hotel
# 3170        -9.367316          Hotel
# 3219        -9.396827          Hotel
# 3249        -9.388475         Hostel
# 6518        -9.407817          Hotel

# %% [markdown]
# **Let's draw, in orange, the possible booking places on map we've drawn previously**

# %%
for lat, lng, booking_name, booking_type in zip(cascais_bookings['Venue Latitude'], cascais_bookings['Venue Longitude'], cascais_bookings['Venue'], cascais_bookings['Venue Category'] ):
    label = '{}, {}'.format(booking_name,booking_type)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='orange',
        fill=True,
        fill_color='#cc8631',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cascais_italian_restaurants)  
    
map_cascais_italian_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Let's try to find the most optimal place to book in terms of distance to all the restaurants**
#
# mpu library provides a function to calculate the Haversine distance between two coordinates.
#
# Haversine determines the great-circle distance between two points on a sphere given their longitudes and latitudes which will suit us perfectly.

# %%
# !pip install mpu
import mpu
# Out:
# Requirement already satisfied: mpu in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.23.1)

# %% [markdown]
# **Lets iterate each booking place and each restaurant to calculate the distance between each possible pairing and append it to a list**

# %%
booking_restaurants_distance = []

for lat_booking, lng_booking, booking_name, booking_type in zip(cascais_bookings['Venue Latitude'], cascais_bookings['Venue Longitude'], cascais_bookings['Venue'], cascais_bookings['Venue Category'] ):
    for lat_restaurant, lng_restaurant, restaurant_name, restaurant_type in zip(cascais_italian_restaurants['Venue Latitude'], cascais_italian_restaurants['Venue Longitude'], cascais_italian_restaurants['Venue'], cascais_italian_restaurants['Venue Category'] ):
        #print(booking_name + ' - ' + restaurant_name + ' = ' '{:.1f}'.format(mpu.haversine_distance((lat_booking, lng_booking), (lat_restaurant, lng_restaurant))) )
        booking_restaurants_distance.append([booking_name,booking_type,lat_booking,lng_booking, restaurant_name,mpu.haversine_distance((lat_booking, lng_booking), (lat_restaurant, lng_restaurant))])

# %% [markdown]
# **Converting that list of pairs into a Pandas Dataframe so we can explore it**

# %%
booking_restaurants_distance_pd = pd.DataFrame(booking_restaurants_distance)
booking_restaurants_distance_pd.columns = ['Booking','Booking Type',   'Booking Latitude',         'Booking Longitude',       'Restaurant',                  'Distance']
booking_restaurants_distance_pd.head()
# Out:
#              Booking Booking Type  Booking Latitude  Booking Longitude  \
# 0  Lagoas Park Hotel        Hotel         38.714855           -9.30945
# 1  Lagoas Park Hotel        Hotel         38.714855           -9.30945
# 2  Lagoas Park Hotel        Hotel         38.714855           -9.30945
# 3  Lagoas Park Hotel        Hotel         38.714855           -9.30945
# 4  Lagoas Park Hotel        Hotel         38.714855           -9.30945
#
#                        Restaurant  Distance
# 0               Trecento Sessanta  4.521263
# 1               Choupana Gordinni  6.538750
# 2  Lamassa - Fresh Handmade Pasta  7.362378
# 3                    Il Siciliano  9.923055
# 4                     Capricciosa  9.332142

# %% [markdown]
# **Lets calculate the average distance per booking place so we can see how well suited each booking place is in terms of distance to the restaurants**

# %%
bookings_restaurants_distance_mean = booking_restaurants_distance_pd.groupby(by=['Booking','Booking Type']).mean()
bookings_restaurants_distance_mean.sort_values(by=['Distance'])
# Out:
#                                                             Booking Latitude  \
# Booking                                       Booking Type
# Somewhere Estoril Guest House                 Hotel                38.705316
# Palácio Estoril Hotel Golf & SPA              Hotel                38.704751
# InterContinental Estoril                      Hotel                38.704330
# Hotel Estoril Eden                            Hotel                38.703827
# Hotel Cascais Miragem                         Hotel                38.702467
# Hotel Estoril 7                               Hotel                38.740338
# The Albatroz Hotel                            Hotel                38.699910
# Farol Hotel                                   Hotel                38.690436
# Pestana Sintra Golf   Conference & Spa Resort Hotel                38.762963
# Grande Real Villa Itália Hotel e Spa          Resort               38.691037
# The Ritz Carlton - Penha Longa Resort         Hotel                38.761060
# Penha Longa Resort                            Hotel                38.761407
# Lagoas Park Hotel                             Hotel                38.714855
# Ibis Lisboa Sintra                            Hotel                38.780450
# Hotel Quinta da Marinha Resort                Hotel                38.707187
# Hotel Vila Galé Collection Palácio dos Arcos  Hotel                38.696575
# Guincho Surf Beach Hostel                     Hostel               38.734984
# Martinhal Cascais                             Resort               38.701860
# Senhora da Guia Cascais Boutique Hotel        Hotel                38.696375
# Sheraton Cascais Resort                       Hotel                38.710105
# The Oitavos Hotel                             Hotel                38.702798
# Hotel Tivoli Palácio de Seteais               Hotel                38.796708
# Moon Hill Hostel                              Hostel               38.798649
# Fortaleza do Guincho                          Hotel                38.728171
#
#                                                             Booking Longitude  \
# Booking                                       Booking Type
# Somewhere Estoril Guest House                 Hotel                 -9.394970
# Palácio Estoril Hotel Golf & SPA              Hotel                 -9.396607
# InterContinental Estoril                      Hotel                 -9.405819
# Hotel Estoril Eden                            Hotel                 -9.407817
# Hotel Cascais Miragem                         Hotel                 -9.410972
# Hotel Estoril 7                               Hotel                 -9.399394
# The Albatroz Hotel                            Hotel                 -9.417177
# Farol Hotel                                   Hotel                 -9.422119
# Pestana Sintra Golf   Conference & Spa Resort Hotel                 -9.367316
# Grande Real Villa Itália Hotel e Spa          Resort                -9.424179
# The Ritz Carlton - Penha Longa Resort         Hotel                 -9.396330
# Penha Longa Resort                            Hotel                 -9.397055
# Lagoas Park Hotel                             Hotel                 -9.309450
# Ibis Lisboa Sintra                            Hotel                 -9.353389
# Hotel Quinta da Marinha Resort                Hotel                 -9.456728
# Hotel Vila Galé Collection Palácio dos Arcos  Hotel                 -9.289266
# Guincho Surf Beach Hostel                     Hostel                -9.455661
# Martinhal Cascais                             Resort                -9.457446
# Senhora da Guia Cascais Boutique Hotel        Hotel                 -9.456344
# Sheraton Cascais Resort                       Hotel                 -9.460854
# The Oitavos Hotel                             Hotel                 -9.466774
# Hotel Tivoli Palácio de Seteais               Hotel                 -9.396827
# Moon Hill Hostel                              Hostel                -9.388475
# Fortaleza do Guincho                          Hotel                 -9.476295
#
#                                                             Distance
# Booking                                       Booking Type
# Somewhere Estoril Guest House                 Hotel         5.195130
# Palácio Estoril Hotel Golf & SPA              Hotel         5.238662
# InterContinental Estoril                      Hotel         5.486354
# Hotel Estoril Eden                            Hotel         5.553244
# Hotel Cascais Miragem                         Hotel         5.672590
# Hotel Estoril 7                               Hotel         5.716189
# The Albatroz Hotel                            Hotel         5.945307
# Farol Hotel                                   Hotel         6.520741
# Pestana Sintra Golf   Conference & Spa Resort Hotel         6.594420
# Grande Real Villa Itália Hotel e Spa          Resort        6.609578
# The Ritz Carlton - Penha Longa Resort         Hotel         6.623328
# Penha Longa Resort                            Hotel         6.664688
# Lagoas Park Hotel                             Hotel         6.817594
# Ibis Lisboa Sintra                            Hotel         8.138747
# Hotel Quinta da Marinha Resort                Hotel         8.442110
# Hotel Vila Galé Collection Palácio dos Arcos  Hotel         8.490182
# Guincho Surf Beach Hostel                     Hostel        8.492403
# Martinhal Cascais                             Resort        8.586767
# Senhora da Guia Cascais Boutique Hotel        Hotel         8.642473
# Sheraton Cascais Resort                       Hotel         8.719376
# The Oitavos Hotel                             Hotel         9.277334
# Hotel Tivoli Palácio de Seteais               Hotel         9.753617
# Moon Hill Hostel                              Hostel        9.812674
# Fortaleza do Guincho                          Hotel         9.924178

# %% [markdown]
# **Now that we know the average distance between each booking place and all the restaurants let's settle for anything less than an average of 6 km of distance**

# %%
bookings_final = bookings_restaurants_distance_mean.loc[(bookings_restaurants_distance_mean['Distance'] < 6 )].reset_index()
bookings_final
# Out:
#                             Booking Booking Type  Booking Latitude  \
# 0             Hotel Cascais Miragem        Hotel         38.702467
# 1                   Hotel Estoril 7        Hotel         38.740338
# 2                Hotel Estoril Eden        Hotel         38.703827
# 3          InterContinental Estoril        Hotel         38.704330
# 4  Palácio Estoril Hotel Golf & SPA        Hotel         38.704751
# 5     Somewhere Estoril Guest House        Hotel         38.705316
# 6                The Albatroz Hotel        Hotel         38.699910
#
#    Booking Longitude  Distance
# 0          -9.410972  5.672590
# 1          -9.399394  5.716189
# 2          -9.407817  5.553244
# 3          -9.405819  5.486354
# 4          -9.396607  5.238662
# 5          -9.394970  5.195130
# 6          -9.417177  5.945307

# %%
for lat, lng, booking_name, booking_type in zip(bookings_final['Booking Latitude'], bookings_final['Booking Longitude'], bookings_final['Booking'], bookings_final['Booking Type'] ):
    label = '{}, {}'.format(booking_name,booking_type)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='red',
        fill=True,
        fill_color='#871010',
        fill_opacity=1,
        parse_html=False).add_to(map_cascais_italian_restaurants)  
    
map_cascais_italian_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **In red we have the recommended Hotels/Resorts/Hostels in terms of average distance to the restaurants, in blue the remaining hotels and in orange the restaurants**
#
# Most of the recomended booking places are also seaside which can be a plus!
